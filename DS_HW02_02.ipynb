# %% [markdown]
# <a href="https://colab.research.google.com/github/anton-akulenko/HW02-DS/blob/main/DS_HW02_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Частина друга: Аналіз файлів**
# Проведіть аналіз файлу 2017_jun_final.csv. Файл містить результати опитування розробників у червні 2017 року.

# %% [markdown]
# Прочитайте файл 2017_jun_final.csv за допомогою методу read_csv

# %%
import pandas as pd
import numpy as np
import requests
import matplotlib.pyplot as plt
from io import StringIO
drive_link = "https://drive.google.com/file/d/1JMYqXipZpz9Y5-vyxvLEO2Y1sRBxqu-U/view?usp=sharing"

file_id = drive_link.split("/")[-2]
export_link = f"https://drive.google.com/uc?id={file_id}&export=download"

response = requests.get(export_link)
response.encoding = 'UTF-8'
csv_data = StringIO(response.text)

data = pd.read_csv(csv_data)
data
# Out:
#          N                 Должность Язык.программирования Специализация  \
# 0        1        Junior QA engineer                   NaN     Manual QA
# 1        2        Junior QA engineer                   NaN     Manual QA
# 2        3         Software Engineer               C#/.NET           NaN
# 3        4         Software Engineer            JavaScript           NaN
# 4        5  Senior Software Engineer            JavaScript           NaN
# ...    ...                       ...                   ...           ...
# 8699  8700               QA engineer                   NaN     Manual QA
# 8700  8701                 Marketing                   NaN           NaN
# 8701  8702  Junior Software Engineer            Ruby/Rails           NaN
# 8702  8703                 Team lead                   NaN           NaN
# 8703  8704  Senior Software Engineer                  Java           NaN
#
#      Общий.опыт.работы Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# ...

# %% [markdown]
# Прочитайте отриману таблицю, використовуючи метод head

# %%
data.head(4)
# Out:
#    N           Должность Язык.программирования Специализация  \
# 0  1  Junior QA engineer                   NaN     Manual QA
# 1  2  Junior QA engineer                   NaN     Manual QA
# 2  3   Software Engineer               C#/.NET           NaN
# 3  4   Software Engineer            JavaScript           NaN
#
#   Общий.опыт.работы Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 0               0.5                          0.5               400
# 1  меньше 3 месяцев             меньше 3 месяцев               430
# 2                 4                            1              2500
# 3                 5                            4              2000
#
#    Изменение.зарплаты.за.12.месяцев    Город     Размер.компании  ...  \
# 0                                 0  Харьков       до 10 человек  ...
# 1                               130  Харьков  свыше 1000 человек  ...
# 2                               800     Киев     до 1000 человек  ...
# ...

# %% [markdown]
# Визначте розмір таблиці за допомогою методу shape

# %%
data.shape
# Out:
# (8704, 25)

# %% [markdown]
# Визначте типи всіх стовпців за допомогою dataframe.dtypes

# %%
data.dtypes
# Out:
# N                                     int64
# Должность                            object
# Язык.программирования                object
# Специализация                        object
# Общий.опыт.работы                    object
# Опыт.работы.на.текущем.месте         object
# Зарплата.в.месяц                      int64
# Изменение.зарплаты.за.12.месяцев      int64
# Город                                object
# Размер.компании                      object
# Тип.компании                         object
# Пол                                  object
# Возраст                               int64
# Образование                          object
# Университет                          object
# Еще.студент                            bool
# Уровень.английского                  object
# Предметная.область                   object
# Дата.заполнения                      object
# User.Agent                           object
# exp                                 float64
# ...

# %% [markdown]
# Порахуйте, яка частка пропусків міститься в кожній колонці (використовуйте методи isnull та sum)

# %%
data.isnull().sum()
# Out:
# N                                      0
# Должность                              0
# Язык.программирования               3850
# Специализация                       7219
# Общий.опыт.работы                      0
# Опыт.работы.на.текущем.месте           0
# Зарплата.в.месяц                       0
# Изменение.зарплаты.за.12.месяцев       0
# Город                                  0
# Размер.компании                        0
# Тип.компании                           0
# Пол                                    0
# Возраст                                0
# Образование                            0
# Университет                          358
# Еще.студент                            0
# Уровень.английского                    0
# Предметная.область                   223
# Дата.заполнения                        0
# User.Agent                             0
# exp                                    0
# current_job_exp                        0
# salary                                 0
# ...

# %% [markdown]
# Видаліть усі стовпці з пропусками, крім стовпця "Мова програмування"

# %%
colums_to_display = ['Язык.программирования'] + list(data.dropna(axis=1, how='any').columns)
data_cleaned = data[colums_to_display]
data_cleaned
# Out:
#      Язык.программирования     N                 Должность Общий.опыт.работы  \
# 0                      NaN     1        Junior QA engineer               0.5
# 1                      NaN     2        Junior QA engineer  меньше 3 месяцев
# 2                  C#/.NET     3         Software Engineer                 4
# 3               JavaScript     4         Software Engineer                 5
# 4               JavaScript     5  Senior Software Engineer    10 и более лет
# ...                    ...   ...                       ...               ...
# 8699                   NaN  8700               QA engineer                 1
# 8700                   NaN  8701                 Marketing               0.5
# 8701            Ruby/Rails  8702  Junior Software Engineer                 1
# 8702                   NaN  8703                 Team lead                 6
# 8703                  Java  8704  Senior Software Engineer                 7
#
# ...

# %% [markdown]
# Знову порахуйте, яка частка пропусків міститься в кожній колонці і переконайтеся, що залишився тільки стовпець "Мова.програмування"

# %%
data_cleaned.isnull().sum()
# Out:
# Язык.программирования               3850
# N                                      0
# Должность                              0
# Общий.опыт.работы                      0
# Опыт.работы.на.текущем.месте           0
# Зарплата.в.месяц                       0
# Изменение.зарплаты.за.12.месяцев       0
# Город                                  0
# Размер.компании                        0
# Тип.компании                           0
# Пол                                    0
# Возраст                                0
# Образование                            0
# Еще.студент                            0
# Уровень.английского                    0
# Дата.заполнения                        0
# User.Agent                             0
# exp                                    0
# current_job_exp                        0
# salary                                 0
# dtype: int64

# %% [markdown]
# Видаліть усі рядки у вихідній таблиці за допомогою методу dropna

# %%
data_update_na = data_cleaned.dropna()
data_update_na
# Out:
#      Язык.программирования     N                 Должность Общий.опыт.работы  \
# 2                  C#/.NET     3         Software Engineer                 4
# 3               JavaScript     4         Software Engineer                 5
# 4               JavaScript     5  Senior Software Engineer    10 и более лет
# 6                  C#/.NET     7  Junior Software Engineer                 1
# 7                      C++     8  Senior Software Engineer                 6
# ...                    ...   ...                       ...               ...
# 8692                  Java  8693         Software Engineer                 5
# 8694               C#/.NET  8695  Junior Software Engineer                 1
# 8695                Python  8696         Software Engineer                 1
# 8701            Ruby/Rails  8702  Junior Software Engineer                 1
# 8703                  Java  8704  Senior Software Engineer                 7
#
# ...

# %% [markdown]
# Визначте новий розмір таблиці за допомогою методу shape

# %%
data_update_na.shape
# Out:
# (4854, 20)

# %% [markdown]
# Створіть нову таблицю python_data, в якій будуть тільки рядки зі спеціалістами, які вказали мову програмування Python

# %%
python_data_only = data_update_na[data_update_na["Язык.программирования"] == "Python"]
python_data_only
# Out:
#      Язык.программирования     N                 Должность Общий.опыт.работы  \
# 12                  Python    13         Software Engineer                 1
# 68                  Python    69         Software Engineer               1.5
# 87                  Python    88  Junior Software Engineer               0.5
# 114                 Python   115  Junior Software Engineer               1.5
# 143                 Python   144  Junior Software Engineer                 1
# ...                    ...   ...                       ...               ...
# 8546                Python  8547         Software Engineer                 5
# 8625                Python  8626         Software Engineer                 4
# 8635                Python  8636  Senior Software Engineer    10 и более лет
# 8673                Python  8674  Junior Software Engineer               0.5
# 8695                Python  8696         Software Engineer                 1
#
# ...

# %% [markdown]
# Визначте розмір таблиці python_data за допомогою методу shape

# %%
python_data_only.shape
# Out:
# (207, 20)

# %% [markdown]
# Використовуючи метод groupby, виконайте групування за стовпчиком "Посада"

# %%
res = data_update_na.groupby("Должность", as_index=False)
res

# %% [markdown]
# Створіть новий DataFrame, де для згрупованих даних за стовпчиком "Посада", виконайте агрегацію даних за допомогою методу agg і знайдіть мінімальне та максимальне значення у стовпчику "Зарплата.в.місяць"

# %%
# res1 = res.groupby("Должность").agg({"Зарплата.в.месяц": (np.min, np.max)})
salary = res.agg({"Зарплата.в.месяц": ("min", "max")})
# res1
# salary = res.agg({'Зарплата.в.месяц': (np.min, np.max)})
salary
# Out:
#                         Должность Зарплата.в.месяц
#                                                min    max
# 0   Data Scientist / Data Analyst             2700   2700
# 1                          DevOps             7000   7000
# 2                       ERP / CRM             2000   2000
# 3                      HTML coder              385    600
# 4        Junior Software Engineer               75   2600
# 5                 Product Manager             3000   3000
# 6        Senior Software Engineer              350   9200
# 7               Software Engineer              100   7000
# 8                System Architect              400  10000
# 9                       Team lead             2500   4000
# 10                 Technical Lead              500  18000

# %% [markdown]
# Створіть функцію fill_avg_salary, яка повертатиме середнє значення заробітної плати на місяць. Використовуйте її для методу apply та створіть новий стовпчик "avg"

# %%
def fill_avg_salary(row):
  min_salary = row['Зарплата.в.месяц']['min']
  max_salary = row['Зарплата.в.месяц']['max']
  return np.average([min_salary, max_salary])

salary['avg'] = salary.apply(fill_avg_salary, axis=1)
salary
# Out:
#                         Должность Зарплата.в.месяц            avg
#                                                min    max
# 0   Data Scientist / Data Analyst             2700   2700  2700.0
# 1                          DevOps             7000   7000  7000.0
# 2                       ERP / CRM             2000   2000  2000.0
# 3                      HTML coder              385    600   492.5
# 4        Junior Software Engineer               75   2600  1337.5
# 5                 Product Manager             3000   3000  3000.0
# 6        Senior Software Engineer              350   9200  4775.0
# 7               Software Engineer              100   7000  3550.0
# 8                System Architect              400  10000  5200.0
# 9                       Team lead             2500   4000  3250.0
# 10                 Technical Lead              500  18000  9250.0

# %% [markdown]
# Створіть описову статистику за допомогою методу describe для нового стовпчика.

# %%
salary["avg"].describe(include='all')
# Out:
# count      11.000000
# mean     3868.636364
# std      2554.599128
# min       492.500000
# 25%      2350.000000
# 50%      3250.000000
# 75%      4987.500000
# max      9250.000000
# Name: avg, dtype: float64

# %% [markdown]
# Збережіть отриману таблицю в CSV файл

# %%
save_data = salary.to_csv("stat.csv", index=True)

# %%
dev_count =python_data_only.groupby("Должность").agg(cnt = ("Должность", "count"))
print(dev_count)
dev_count.plot.pie(
    y="cnt",
    startangle=5,
    figsize=(8, 8),
    legend=False,
    shadow=False,
    explode=[0.15, 0, 0, 0, 0],
    labeldistance=1.15,
    fontsize=0
)
total = np.sum(dev_count['cnt'])
labels = [
    f"{n} ({v/total:.2%})"
    for n, v in zip(
        dev_count['cnt'].keys(),
        dev_count['cnt'].values,
    )
]
plt.legend(
    loc="best",
    labels=labels,
)
plt.tight_layout()
plt.title("Python devs by position", fontsize=16, color="b")
# Out:
#                           cnt
# Должность
# Junior Software Engineer   63
# Senior Software Engineer   31
# Software Engineer         100
# System Architect            2
# Technical Lead             11
# Text(0.5, 1.0, 'Python devs by position')

# %%
plt.plot(salary['Должность'],
         salary['Зарплата.в.месяц']['min'],
         label="Min. salary",
         color='b',
         linestyle = '--',
         marker = 'D')
plt.grid()
plt.plot(salary['Должность'],
         salary['Зарплата.в.месяц']['max'],
         label="Max. salary",
         color='r',
         linestyle = ':',
         marker = '+',)
plt.plot(salary['Должность'],
         salary['avg'],
         label="Avg. salary",
         color='g',
         linestyle = '-.',
         marker = '*',)

plt.xlabel("Position")
plt.ylabel("Salary")
plt.xticks(rotation=90, fontsize='x-small')
plt.title("Salary Python Developers вin 2017")
plt.legend(loc='best')
plt.tight_layout()
plt.show()
